# %% [markdown]
# ## Data transformation

# %%
import pandas as pd

df = pd.read_csv('data_cleaning_sample.csv')

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
# let's do some cleaning first

df = df.dropna().drop_duplicates()

# %%
df
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019

# %%
df2 = pd.read_csv('data.csv')

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.sort_values('Year')
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2 = df2.sort_values(['IMDb','Year','BoxOffice(INR Crore)'], ascending = False)

# %%
# now we have a df which is better according to movies 
# but the indexing is changed so we'll reorder it 

df2.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       2          Aamir Khan                    Dangal  2016
# 1       5  Ayushmann Khurrana                 Andhadhun  2018
# 2      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 3       6       Rajkummar Rao                     Stree  2018
# 4       0      Shah Rukh Khan                   Pathaan  2023
# 5       8        Akshay Kumar                Good Newwz  2019
# 6       4       Ranveer Singh                 Padmaavat  2018
# 7       7      Hrithik Roshan                       War  2019
# 8      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 9       1         Salman Khan           Tiger Zinda Hai  2017
# 10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11      3       Ranbir Kapoor                Brahmastra  2022
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1          Thriller                   111   8.3
# ...

# %%
df2.reset_index(drop=True)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True, inplace = True )

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# ---
# ## sort index

# %%
import pandas as pd

df = pd.read_csv('data_cleaning_sample.csv')

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
# using drop

df = df.dropna()

# %%
df.sort_values('Age')
# Out:
#     Name   Age         City Gender              Email   Join Date
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020

# %% [markdown]
# ## Now Using sort_index

# %%
df.sort_index()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %% [markdown]
# ---

# %% [markdown]
# ## Creating Ranking

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# providing ranking on the basis of IMDb 
df2["Rank"] = df2["IMDb"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4       Shah Rukh Khan                   Pathaan  2023           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Hrithik Roshan                       War  2019           Action
# 8         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11       Ranbir Kapoor                Brahmastra  2022          Fantasy
#
# ...

# %% [markdown]
# ## Renaming and Changing Columns Order

# %%
# Rename
df2 = df2.rename(columns= {'Rank':'Ranking','Film':'Movie'})

# %%
# Chaning order 
df2 = df2[['Movie','IMDb','Actor','Year','BoxOffice(INR Crore)','Genre','Ranking']]

# %%
df2
# Out:
#                        Movie  IMDb               Actor  Year  \
# 0                     Dangal   8.4          Aamir Khan  2016
# 1                  Andhadhun   8.3  Ayushmann Khurrana  2018
# 2   Uri: The Surgical Strike   8.2       Vicky Kaushal  2019
# 3                      Stree   7.5       Rajkummar Rao  2018
# 4                    Pathaan   7.2      Shah Rukh Khan  2023
# 5                 Good Newwz   7.0        Akshay Kumar  2019
# 6                  Padmaavat   7.0       Ranveer Singh  2018
# 7                        War   6.5      Hrithik Roshan  2019
# 8      Badrinath Ki Dulhania   6.1        Varun Dhawan  2017
# 9            Tiger Zinda Hai   6.0         Salman Khan  2017
# 10         Bhool Bhulaiyaa 2   5.9       Kartik Aaryan  2022
# 11                Brahmastra   5.6       Ranbir Kapoor  2022
#
#     BoxOffice(INR Crore)            Genre  Ranking
# 0                   2024        Biography      1.0
# 1                    111         Thriller      2.0
# ...

# %%
df2[['Actor','Movie','BoxOffice(INR Crore)']]
# Out:
#                  Actor                     Movie  BoxOffice(INR Crore)
# 0           Aamir Khan                    Dangal                  2024
# 1   Ayushmann Khurrana                 Andhadhun                   111
# 2        Vicky Kaushal  Uri: The Surgical Strike                   342
# 3        Rajkummar Rao                     Stree                   180
# 4       Shah Rukh Khan                   Pathaan                  1050
# 5         Akshay Kumar                Good Newwz                   318
# 6        Ranveer Singh                 Padmaavat                   585
# 7       Hrithik Roshan                       War                   475
# 8         Varun Dhawan     Badrinath Ki Dulhania                   201
# 9          Salman Khan           Tiger Zinda Hai                   565
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2                   266
# 11       Ranbir Kapoor                Brahmastra                   431

# %%
df2
# Out:
#                        Movie  IMDb               Actor  Year  \
# 0                     Dangal   8.4          Aamir Khan  2016
# 1                  Andhadhun   8.3  Ayushmann Khurrana  2018
# 2   Uri: The Surgical Strike   8.2       Vicky Kaushal  2019
# 3                      Stree   7.5       Rajkummar Rao  2018
# 4                    Pathaan   7.2      Shah Rukh Khan  2023
# 5                 Good Newwz   7.0        Akshay Kumar  2019
# 6                  Padmaavat   7.0       Ranveer Singh  2018
# 7                        War   6.5      Hrithik Roshan  2019
# 8      Badrinath Ki Dulhania   6.1        Varun Dhawan  2017
# 9            Tiger Zinda Hai   6.0         Salman Khan  2017
# 10         Bhool Bhulaiyaa 2   5.9       Kartik Aaryan  2022
# 11                Brahmastra   5.6       Ranbir Kapoor  2022
#
#     BoxOffice(INR Crore)            Genre  Ranking
# 0                   2024        Biography      1.0
# 1                    111         Thriller      2.0
# ...

# %%
df3 = df2[['Movie',]]

# %%
df3
# Out:
#                        Movie
# 0                     Dangal
# 1                  Andhadhun
# 2   Uri: The Surgical Strike
# 3                      Stree
# 4                    Pathaan
# 5                 Good Newwz
# 6                  Padmaavat
# 7                        War
# 8      Badrinath Ki Dulhania
# 9            Tiger Zinda Hai
# 10         Bhool Bhulaiyaa 2
# 11                Brahmastra

# %% [markdown]
# ---

# %%
# creative area

df3["Cause why not"] = df2['IMDb'].rank(ascending = False )

# %%
df3
# Out:
#                        Movie  Cause why not
# 0                     Dangal            1.0
# 1                  Andhadhun            2.0
# 2   Uri: The Surgical Strike            3.0
# 3                      Stree            4.0
# 4                    Pathaan            5.0
# 5                 Good Newwz            6.5
# 6                  Padmaavat            6.5
# 7                        War            8.0
# 8      Badrinath Ki Dulhania            9.0
# 9            Tiger Zinda Hai           10.0
# 10         Bhool Bhulaiyaa 2           11.0
# 11                Brahmastra           12.0

# %%
df3['NewColumn'] = 0

# %%
df3
# Out:
#                        Movie  Cause why not  NewColumn
# 0                     Dangal            1.0          0
# 1                  Andhadhun            2.0          0
# 2   Uri: The Surgical Strike            3.0          0
# 3                      Stree            4.0          0
# 4                    Pathaan            5.0          0
# 5                 Good Newwz            6.5          0
# 6                  Padmaavat            6.5          0
# 7                        War            8.0          0
# 8      Badrinath Ki Dulhania            9.0          0
# 9            Tiger Zinda Hai           10.0          0
# 10         Bhool Bhulaiyaa 2           11.0          0
# 11                Brahmastra           12.0          0

# %%
df3['SwapCase'] = df3['Movie'].str.swapcase()

# %%
df3
# Out:
#                        Movie  Cause why not  NewColumn  \
# 0                     Dangal            1.0          0
# 1                  Andhadhun            2.0          0
# 2   Uri: The Surgical Strike            3.0          0
# 3                      Stree            4.0          0
# 4                    Pathaan            5.0          0
# 5                 Good Newwz            6.5          0
# 6                  Padmaavat            6.5          0
# 7                        War            8.0          0
# 8      Badrinath Ki Dulhania            9.0          0
# 9            Tiger Zinda Hai           10.0          0
# 10         Bhool Bhulaiyaa 2           11.0          0
# 11                Brahmastra           12.0          0
#
#                     SwapCase
# 0                     dANGAL
# 1                  aNDHADHUN
# 2   uRI: tHE sURGICAL sTRIKE
# 3                      sTREE
# 4                    pATHAAN
# 5                 gOOD nEWWZ
# 6                  pADMAAVAT
# ...

# %%
df3['NewColumn'] = df2['Genre']

# %%
df3
# Out:
#                        Movie  Cause why not        NewColumn  \
# 0                     Dangal            1.0        Biography
# 1                  Andhadhun            2.0         Thriller
# 2   Uri: The Surgical Strike            3.0           Action
# 3                      Stree            4.0    Horror Comedy
# 4                    Pathaan            5.0           Action
# 5                 Good Newwz            6.5           Comedy
# 6                  Padmaavat            6.5       Historical
# 7                        War            8.0           Action
# 8      Badrinath Ki Dulhania            9.0  Romantic Comedy
# 9            Tiger Zinda Hai           10.0           Action
# 10         Bhool Bhulaiyaa 2           11.0    Horror Comedy
# 11                Brahmastra           12.0          Fantasy
#
#                     SwapCase
# 0                     dANGAL
# 1                  aNDHADHUN
# 2   uRI: tHE sURGICAL sTRIKE
# 3                      sTREE
# ...

# %%
# renaming again
df3.rename(columns = {'NewColumn':'Genre'}, inplace = True )

# %%
df3
# Out:
#                        Movie  Cause why not            Genre  \
# 0                     Dangal            1.0        Biography
# 1                  Andhadhun            2.0         Thriller
# 2   Uri: The Surgical Strike            3.0           Action
# 3                      Stree            4.0    Horror Comedy
# 4                    Pathaan            5.0           Action
# 5                 Good Newwz            6.5           Comedy
# 6                  Padmaavat            6.5       Historical
# 7                        War            8.0           Action
# 8      Badrinath Ki Dulhania            9.0  Romantic Comedy
# 9            Tiger Zinda Hai           10.0           Action
# 10         Bhool Bhulaiyaa 2           11.0    Horror Comedy
# 11                Brahmastra           12.0          Fantasy
#
#                     SwapCase
# 0                     dANGAL
# 1                  aNDHADHUN
# 2   uRI: tHE sURGICAL sTRIKE
# 3                      sTREE
# ...

# %%
# changing row name of bHOOL bHULAIYAA 2
# df3.loc[10,"SwapCase"]
df3['SwapCase'] = df3['SwapCase'].replace('bHOOL bHULAIYAA 2', 'KYUUUU BHULLLL GAYEEEE 2')

# %%
df3
# Out:
#                        Movie  Cause why not            Genre  \
# 0                     Dangal            1.0        Biography
# 1                  Andhadhun            2.0         Thriller
# 2   Uri: The Surgical Strike            3.0           Action
# 3                      Stree            4.0    Horror Comedy
# 4                    Pathaan            5.0           Action
# 5                 Good Newwz            6.5           Comedy
# 6                  Padmaavat            6.5       Historical
# 7                        War            8.0           Action
# 8      Badrinath Ki Dulhania            9.0  Romantic Comedy
# 9            Tiger Zinda Hai           10.0           Action
# 10         Bhool Bhulaiyaa 2           11.0    Horror Comedy
# 11                Brahmastra           12.0          Fantasy
#
#                     SwapCase
# 0                     dANGAL
# 1                  aNDHADHUN
# 2   uRI: tHE sURGICAL sTRIKE
# 3                      sTREE
# ...
