# %% [markdown]
# ### DATAFRAMES - Basically a DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
#data of marks abtained by student in subjects from "DICTIONARY"
import pandas as pd

data = {
    "Krish" : [83,92,89,79,97],
    "Aditya" : [85,94,84,96,86],
    "Salu bhai":[90,97,97,95,89],
    "Ravi" : [96,84,89,93,79]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Krish  Aditya  Salu bhai  Ravi
# 0     83      85         90    96
# 1     92      94         97    84
# 2     89      84         97    89
# 3     79      96         95    93
# 4     97      86         89    79

# %% [markdown]
# ---

# %%
# from python "LISTS"

data = [
["Alice",   25],
["Bob",     30],
["Charlie", 35] ]
df = pd.DataFrame(data, columns=["Name", "Age"])
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
data = [
["Alice",   25],
["Bob",     30],
["Charlie", 35] ]
df = pd.DataFrame(data)

# %%
df
# Out:
#          0   1
# 0    Alice  25
# 1      Bob  30
# 2  Charlie  35

# %% [markdown]
# ---

# %%
# Dict of lists 

data = {
    
"Name":   ["Alice", "Bob", "Charlie"],
"Age" :   [25, 30, 35]
    
}
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# From Numpy ARRAY 

import numpy as np

arr = np.array([[47,83,20],[83,91,58]])

df = pd.DataFrame(arr,columns =['harry','Larry','Carry'])

# %%
df
# Out:
#    harry  Larry  Carry
# 0     47     83     20
# 1     83     91     58

# %%
# From CSV Files

df = pd.read_csv("data.csv", sep = ',')

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# From a JSON file 

df = pd.read_json("data.json")

# %%
df
# Out:
#                                                          user  \
# name                                              Krish Kumar
# age                                                        21
# location                                                India
# interests              [data science, AI, basketball, coding]
# education   {'degree': 'Bachelor of Engineering', 'univers...
# skills                                                    NaN
# status                                                    NaN
# repository                                                NaN
#
#                                                  project
# name                                Data Science Journey
# age                                                  NaN
# location                                             NaN
# interests                                            NaN
# education                                            NaN
# skills      [Python, NumPy, Pandas, Matplotlib, Seaborn]
# ...

# %%
# from a XLSX file (Excel file )

df = pd.read_excel("sample_data.xlsx")

# %%
df
# Out:
#           Name  Age Location                             Interests  \
# 0  Krish Kumar   21    India  data science, AI, basketball, coding
#
#                     Degree                        University  \
# 0  Bachelor of Engineering  Savitribai Phule Pune University
#
#                                       Certifications
# 0  TCS iON Career Edge - Young Professional, Prom...

# %%
# From SQL Databases
import sqlite3

conn = sqlite3.connect("data.db")

df = pd.read_sql("SELECT * FROM Books", conn)

# %%
df
# Out:
#    BookID                  Title               Author        Genre  \
# 0       1  To Kill a Mockingbird           Harper Lee      Fiction
# 1       2                   1984        George Orwell    Dystopian
# 2       3       The Great Gatsby  F. Scott Fitzgerald      Classic
# 3       4             The Hobbit       J.R.R. Tolkien      Fantasy
# 4       5                Sapiens    Yuval Noah Harari  Non-fiction
#
#    YearPublished
# 0           1960
# 1           1949
# 2           1925
# 3           1937
# 4           2011

# %% [markdown]
# ---

# %%
### From the Web (Example: CSV from URL)
